# %%
import parser

# %%
parser.parse_data_folder("../data")
# Out:
#      property_id date_obtained    price property_type  livable_area  \
# 0       11326221      19052024   279000     APARTMENT          94.0
# 1       11386911      19052024  1090000         HOUSE           NaN
# 2       11376909      19052024   269000     APARTMENT          99.0
# 3       11362707      19052024   563000         HOUSE         187.0
# 4       11361176      19052024   995000         HOUSE           NaN
# ...          ...           ...      ...           ...           ...
# 2379    11340880      19052024   399000     APARTMENT         138.0
# 2380    11374289      18052024   299000         HOUSE         263.0
# 2381    11374289      16052024   299000         HOUSE         263.0
# 2382    11374289      19052024   299000         HOUSE         263.0
# 2383    11136161      19052024   249000     APARTMENT          66.0
#
#      heating_type has_photovoltaic_panels has_double_glazing  number_of_rooms  \
# ...

# %%
_4.date_obtained.unique()
# Out:
# array(['19052024', '18052024', '16052024', '21052024'], dtype=object)

# %%
import os
import requests
import scraper
import parser

# %%
house_url = 'https://www.immoweb.be/en/classified/house/for-sale/drongen/9031/11400120'

# %%
scraper.save_house_data(house_url)
# Out:
# Full source code saved to /Users/simon/Desktop/personal/immo_datacollection/house_scraping_project/data/11400120/full_source_24052024.html

# %%
parser.parse_data_folder(data_folder)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/simon/Desktop/personal/immo_datacollection/house_scraping_project/src/run_pipeline_manually.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell:/Users/simon/Desktop/personal/immo_datacollection/house_scraping_project/src/run_pipeline_manually.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> parser.parse_data_folder(data_folder)
#
# NameError: name 'data_folder' is not defined

# %%
parser.extract_info('/Users/simon/Desktop/personal/immo_datacollection/house_scraping_project/data/11400120/full_source_24052024.html')
# Out:
# {'property_id': '11400120',
#  'date_obtained': '24052024',
#  'price': 440000,
#  'property_type': 'HOUSE',
#  'livable_area': 249,
#  'heating_type': None,
#  'has_photovoltaic_panels': None,
#  'has_double_glazing': None,
#  'number_of_rooms': None,
#  'number_of_bathrooms': 1,
#  'number_of_bedrooms': 3,
#  'number_of_toilets': 2,
#  'has_living_room': True,
#  'has_dining_room': None,
#  'has_attic': True,
#  'has_basement': None,
#  'has_terrace': None,
#  'terrace_surface': None,
#  'has_garden': None,
#  'garden_surface': None,
#  'energy_label': 'D',
#  'primary_energy_consumption': 364,
#  'postal_code': '9031',
#  'latitude': 51.0539771,
#  'longitude': 3.618189,
#  'year_built': 1999,
#  'building_condition': None,
#  'floor_number': None,
#  'total_floors': None,
#  'property_size': 800,
#  'flood_zone_type': None,
#  'cadastral_income': 1224}
